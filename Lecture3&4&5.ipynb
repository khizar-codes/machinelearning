# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir('C:\\Users\\Khizar\\Desktop\\Semester - Spring 2021\\5 - Machine Learning 4375\\CSV')
path = os.getcwd()
path
# Out:
# 'C:\\Users\\Khizar\\Desktop\\Semester - Spring 2021\\5 - Machine Learning 4375\\CSV'

# %%
WageDF = pd.read_csv('Wage.csv')

# %%
WageDF.head()
# Out:
#    year  age            maritl      race     education              region  \
# 0  2003   18  1. Never Married  2. Black    2. HS Grad  2. Middle Atlantic
# 1  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 2  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 3  2003   19  1. Never Married  2. Black  1. < HS Grad  2. Middle Atlantic
# 4  2003   19  1. Never Married  1. White    2. HS Grad  2. Middle Atlantic
#
#          jobclass          health health_ins   logwage       wage
# 0   1. Industrial  2. >=Very Good     1. Yes  4.255273  70.476020
# 1   1. Industrial  2. >=Very Good      2. No  3.301030  27.140579
# 2   1. Industrial       1. <=Good      2. No  4.000000  54.598150
# 3  2. Information  2. >=Very Good      2. No  4.176091  65.110854
# 4   1. Industrial  2. >=Very Good      2. No  3.949390  51.903696

# %%
WageDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        3000 non-null   int64
#  1   age         3000 non-null   int64
#  2   maritl      3000 non-null   object
#  3   race        3000 non-null   object
#  4   education   3000 non-null   object
#  5   region      3000 non-null   object
#  6   jobclass    3000 non-null   object
#  7   health      3000 non-null   object
#  8   health_ins  3000 non-null   object
#  9   logwage     3000 non-null   float64
#  10  wage        3000 non-null   float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 257.9+ KB

# %%
WageDF.describe()
# Out:
#               year          age      logwage         wage
# count  3000.000000  3000.000000  3000.000000  3000.000000
# mean   2005.791000    42.414667     4.653905   111.703608
# std       2.026167    11.542406     0.351753    41.728595
# min    2003.000000    18.000000     3.000000    20.085537
# 25%    2004.000000    33.750000     4.447158    85.383940
# 50%    2006.000000    42.000000     4.653213   104.921506
# 75%    2008.000000    51.000000     4.857332   128.680488
# max    2009.000000    80.000000     5.763128   318.342430

# %%
WageDF.tail()
# Out:
#       year  age       maritl      race           education  \
# 2995  2009   71   2. Married  1. White          2. HS Grad
# 2996  2009   73   2. Married  1. White        1. < HS Grad
# 2997  2009   74   2. Married  1. White          2. HS Grad
# 2998  2009   75   2. Married  1. White     4. College Grad
# 2999  2009   76  4. Divorced  1. White  5. Advanced Degree
#
#                   region        jobclass          health health_ins   logwage  \
# 2995  2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes  4.591065
# 2996  2. Middle Atlantic   1. Industrial       1. <=Good      2. No  4.505150
# 2997  2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes  4.602060
# 2998  2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes  4.447158
# 2999  2. Middle Atlantic  2. Information  2. >=Very Good     1. Yes  5.176091
#
#             wage
# 2995   98.599344
# 2996   90.481913
# 2997   99.689464
# 2998   85.383940
# 2999  176.989650

# %%
WageDF.columns
# Out:
# Index(['year', 'age', 'maritl', 'race', 'education', 'region', 'jobclass',
#        'health', 'health_ins', 'logwage', 'wage'],
#       dtype='object')

# %%
Variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-18a7c5bf38b7> in <module>
# ----> 1 Variable
#
# NameError: name 'Variable' is not defined

# %%
Variable = ['year', 'age', 'maritl', 'race', 'education', 'region', 'jobclass',
       'health', 'health_ins', 'logwage', 'wage']

# %%
Variable
# Out:
# ['year',
#  'age',
#  'maritl',
#  'race',
#  'education',
#  'region',
#  'jobclass',
#  'health',
#  'health_ins',
#  'logwage',
#  'wage']

# %%
WageDF['maritl_cd'] = WageDF['maritl'].str.slice(0, 1).astype(str).astype(int)

# %%
WageDF.head()
# Out:
#    year  age            maritl      race     education              region  \
# 0  2003   18  1. Never Married  2. Black    2. HS Grad  2. Middle Atlantic
# 1  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 2  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 3  2003   19  1. Never Married  2. Black  1. < HS Grad  2. Middle Atlantic
# 4  2003   19  1. Never Married  1. White    2. HS Grad  2. Middle Atlantic
#
#          jobclass          health health_ins   logwage       wage  maritl_cd
# 0   1. Industrial  2. >=Very Good     1. Yes  4.255273  70.476020          1
# 1   1. Industrial  2. >=Very Good      2. No  3.301030  27.140579          1
# 2   1. Industrial       1. <=Good      2. No  4.000000  54.598150          1
# 3  2. Information  2. >=Very Good      2. No  4.176091  65.110854          1
# 4   1. Industrial  2. >=Very Good      2. No  3.949390  51.903696          1

# %%
WageDF['maritl_cd2'] = WageDF['maritl'].str.slice(0, 1).astype(int)

# %%
WageDF.head()
# Out:
#    year  age            maritl      race     education              region  \
# 0  2003   18  1. Never Married  2. Black    2. HS Grad  2. Middle Atlantic
# 1  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 2  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 3  2003   19  1. Never Married  2. Black  1. < HS Grad  2. Middle Atlantic
# 4  2003   19  1. Never Married  1. White    2. HS Grad  2. Middle Atlantic
#
#          jobclass          health health_ins   logwage       wage  maritl_cd  \
# 0   1. Industrial  2. >=Very Good     1. Yes  4.255273  70.476020          1
# 1   1. Industrial  2. >=Very Good      2. No  3.301030  27.140579          1
# 2   1. Industrial       1. <=Good      2. No  4.000000  54.598150          1
# 3  2. Information  2. >=Very Good      2. No  4.176091  65.110854          1
# 4   1. Industrial  2. >=Very Good      2. No  3.949390  51.903696          1
#
#    maritl_cd2
# 0           1
# 1           1
# ...

# %%
WageDF.drop('maritl_cd', axis=1)
# Out:
#       year  age            maritl      race           education  \
# 0     2003   18  1. Never Married  2. Black          2. HS Grad
# 1     2003   19  1. Never Married  1. White        1. < HS Grad
# 2     2003   19  1. Never Married  1. White        1. < HS Grad
# 3     2003   19  1. Never Married  2. Black        1. < HS Grad
# 4     2003   19  1. Never Married  1. White          2. HS Grad
# ...    ...  ...               ...       ...                 ...
# 2995  2009   71        2. Married  1. White          2. HS Grad
# 2996  2009   73        2. Married  1. White        1. < HS Grad
# 2997  2009   74        2. Married  1. White          2. HS Grad
# 2998  2009   75        2. Married  1. White     4. College Grad
# 2999  2009   76       4. Divorced  1. White  5. Advanced Degree
#
#                   region        jobclass          health health_ins   logwage  \
# 0     2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes  4.255273
# ...

# %%
WageDF.drop('maritl_cd2', axis=1)
# Out:
#       year  age            maritl      race           education  \
# 0     2003   18  1. Never Married  2. Black          2. HS Grad
# 1     2003   19  1. Never Married  1. White        1. < HS Grad
# 2     2003   19  1. Never Married  1. White        1. < HS Grad
# 3     2003   19  1. Never Married  2. Black        1. < HS Grad
# 4     2003   19  1. Never Married  1. White          2. HS Grad
# ...    ...  ...               ...       ...                 ...
# 2995  2009   71        2. Married  1. White          2. HS Grad
# 2996  2009   73        2. Married  1. White        1. < HS Grad
# 2997  2009   74        2. Married  1. White          2. HS Grad
# 2998  2009   75        2. Married  1. White     4. College Grad
# 2999  2009   76       4. Divorced  1. White  5. Advanced Degree
#
#                   region        jobclass          health health_ins   logwage  \
# 0     2. Middle Atlantic   1. Industrial  2. >=Very Good     1. Yes  4.255273
# ...

# %%
WageDF.drop('maritl_cd', axis=1, inplace=true
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-cad8bf2c0134> in <module>
# ----> 1 WageDF.drop('maritl_cd', axis=1, inplace=true
#       2         )
#
# NameError: name 'true' is not defined

# %%
WageDF.drop('maritl_cd', axis=1, inplace=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-fa4207d816f5> in <module>
# ----> 1 WageDF.drop('maritl_cd', axis=1, inplace=true)
#
# NameError: name 'true' is not defined

# %%
WageDF.drop('maritl_cd', axis=1, inplace=True)

# %%
WageDF.drop('maritl_cd2', axis=1, inplace=True)

# %%
WageDF.head()
# Out:
#    year  age            maritl      race     education              region  \
# 0  2003   18  1. Never Married  2. Black    2. HS Grad  2. Middle Atlantic
# 1  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 2  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 3  2003   19  1. Never Married  2. Black  1. < HS Grad  2. Middle Atlantic
# 4  2003   19  1. Never Married  1. White    2. HS Grad  2. Middle Atlantic
#
#          jobclass          health health_ins   logwage       wage
# 0   1. Industrial  2. >=Very Good     1. Yes  4.255273  70.476020
# 1   1. Industrial  2. >=Very Good      2. No  3.301030  27.140579
# 2   1. Industrial       1. <=Good      2. No  4.000000  54.598150
# 3  2. Information  2. >=Very Good      2. No  4.176091  65.110854
# 4   1. Industrial  2. >=Very Good      2. No  3.949390  51.903696

# %%
WageDF.to_csv(path + '\\' + 'Wage_New_501.csv', index=False, sep=',', header='true')

# %%
sns.displot(WageDF, x='age', kde=True)

# %%
sns.scatterplot(x='age', y='wage', data=WageDF)
# Out:
# <AxesSubplot:xlabel='age', ylabel='wage'>

# %%
sns.scatterplot(x='year', y='wage', data=WageDF)
# Out:
# <AxesSubplot:xlabel='year', ylabel='wage'>

# %%
sns.boxplot(x='education', y='wage', data=WageDF)
# Out:
# <AxesSubplot:xlabel='education', ylabel='wage'>

# %%
WageDF.head()
# Out:
#    year  age            maritl      race     education              region  \
# 0  2003   18  1. Never Married  2. Black    2. HS Grad  2. Middle Atlantic
# 1  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 2  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 3  2003   19  1. Never Married  2. Black  1. < HS Grad  2. Middle Atlantic
# 4  2003   19  1. Never Married  1. White    2. HS Grad  2. Middle Atlantic
#
#          jobclass          health health_ins   logwage       wage
# 0   1. Industrial  2. >=Very Good     1. Yes  4.255273  70.476020
# 1   1. Industrial  2. >=Very Good      2. No  3.301030  27.140579
# 2   1. Industrial       1. <=Good      2. No  4.000000  54.598150
# 3  2. Information  2. >=Very Good      2. No  4.176091  65.110854
# 4   1. Industrial  2. >=Very Good      2. No  3.949390  51.903696

# %%
correlation = WageDF.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3412690556f6> in <module>
# ----> 1 correlation = WageDF.corr()
#
# NameError: name 'WageDF' is not defined

# %%
WageDF.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-95b7cccca8fd> in <module>
# ----> 1 WageDF.corr()
#
# NameError: name 'WageDF' is not defined

# %%
Wage
