# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.chdir('C:\\Users\\Khizar\\Desktop\\Semester - Spring 2021\\5 - Machine Learning 4375\\CSV')
path = os.getcwd()
path

df = pd.read_csv('wine_fraud.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   object
#  12  type                  6497 non-null   object
# dtypes: float64(11), object(2)
# memory usage: 660.0+ KB

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# 2      9.8   Legit  red
# 3      9.8   Legit  red
# 4      9.4   Legit  red

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol
# count  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801
# std       0.160787     0.148806     1.192712
# min       2.720000     0.220000     8.000000
# 25%       3.110000     0.430000     9.500000
# 50%       3.210000     0.510000    10.300000
# 75%       3.320000     0.600000    11.300000
# max       4.010000     2.000000    14.900000

# %%
df['quality'].unique()
# Out:
# array(['Legit', 'Fraud'], dtype=object)

# %%
sns.countplot(data=df, x='quality', order=df['quality'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
sns.countplot(data=df, x='type', order=df['type'].value_counts().index, hue='quality')
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
mapping = {'Legit': 1, 'Fraud': 0}
df.replace({'Legit': mapping, 'Fraud': mapping})
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol quality   type
# 0         9.4       1    red
# 1         9.8       1    red
# 2         9.8       1    red
# 3         9.8       1    red
# 4         9.4       1    red
# ...       ...     ...    ...
# 6492     11.2       1  white
# 6493      9.6       1  white
# 6494      9.4       1  white
# 6495     12.8       1  white
# 6496     11.8       1  white
#
# [6497 rows x 13 columns]

# %%
df['quality'].unique()
# Out:
# array([1, 0], dtype=object)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df = pd.get_dummies(df, columns=['type'])

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality  type_red  type_white
# 0      9.4       1         1           0
# 1      9.8       1         1           0
# 2      9.8       1         1           0
# 3      9.8       1         1           0
# 4      9.4       1         1           0

# %%
x = pd.get_dummies(df.drop('quality', axis = 1), drop_first = True)
y = df['quality']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 101)

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  type_red  type_white
# 0         9.4         1           0
# 1         9.8         1           0
# 2         9.8         1           0
# 3         9.8         1           0
# 4         9.4         1           0
# ...       ...       ...         ...
# 6492     11.2         0           1
# 6493      9.6         0           1
# 6494      9.4         0           1
# 6495     12.8         0           1
# 6496     11.8         0           1
#
# [6497 rows x 13 columns]

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6492    1
# 6493    1
# 6494    1
# 6495    1
# 6496    1
# Name: quality, Length: 6497, dtype: object

# %%
from sklearn.svm import SVC

# %%
y=y.astype('int')
model = SVC(kernel='linear', C=0.5)
model.fit(x, y)
# Out:
# SVC(C=0.5, kernel='linear')

# %%
from sklearn import svm
from svm_margin_plot import plot_svm_boundary

# %%
plot_svm_boundary(model, x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-a73d83662d27> in <module>
# ----> 1 plot_svm_boundary(model, x, y)
#
# ~\svm_margin_plot.py in plot_svm_boundary(model, X, y)
#      25     YY, XX = np.meshgrid(yy, xx)
#      26     xy = np.vstack([XX.ravel(), YY.ravel()]).T
# ---> 27     Z = model.decision_function(xy).reshape(XX.shape)
#      28
#      29     # plot decision boundary and margins
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in decision_function(self, X)
#     581         transformation of ovo decision function.
#     582         """
# --> 583         dec = self._decision_function(X)
#     584         if self.decision_function_shape == 'ovr' and len(self.classes_) > 2:
#     585             return _ovr_decision_function(dec < 0, -dec, len(self.classes_))
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _decision_function(self, X)
#     406         # NOTE: _validate_for_predict contains check for is_fitted
#     407         # hence must be placed before any other attributes are used.
# --> 408         X = self._validate_for_predict(X)
#     409         X = self._compute_kernel(X)
#     410
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _validate_for_predict(self, X)
#     482                                  (X.shape[1], self.shape_fit_[0]))
#     483         elif not callable(self.kernel) and X.shape[1] != self.shape_fit_[1]:
# --> 484             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     485                              "the number of features at training time" %
#     486                              (X.shape[1], self.shape_fit_[1]))
#
# ValueError: X.shape[1] = 2 should be equal to 13, the number of features at training time

# %%
from sklearn.model_selection import GridSearchCV
svm = SVC()
param_grid = {'C':[0.01, 0.1, 1], 'kernel':['linear', 'rbf', 'sigmoid', 'poly'], 'degree': [1,2,3]}
grid = GridSearchCV(svm, param_grid)

# %%
grid.fit(x,y)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1], 'degree': [1, 2, 3],
#                          'kernel': ['linear', 'rbf', 'sigmoid', 'poly']})

# %%
grid.best_score_
# Out:
# 0.9621364363119559

# %%
grid.best_params_
# Out:
# {'C': 0.01, 'degree': 1, 'kernel': 'linear'}

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix
plot_confusion_matrix(model, x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-07b28e28a6df> in <module>
#       1 from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix
# ----> 2 plot_confusion_matrix(model, x_test, y_test)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py in plot_confusion_matrix(estimator, X, y_true, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax)
#     218
#     219     y_pred = estimator.predict(X)
# --> 220     cm = confusion_matrix(y_true, y_pred, sample_weight=sample_weight,
#     221                           labels=labels, normalize=normalize)
#     222
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     274
#     275     """
# --> 276     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     277     if y_type not in ("binary", "multiclass"):
#     278         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      88
#      89     if len(y_type) > 1:
# ---> 90         raise ValueError("Classification metrics can't handle a mix of {0} "
#      91                          "and {1} targets".format(type_true, type_pred))
#      92
#
# ValueError: Classification metrics can't handle a mix of unknown and binary targets
